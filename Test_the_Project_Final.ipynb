# %%
# Cell 1: Mount Drive and Install Dependencies

import os
import sys
from google.colab import drive

# 1. Mount Google Drive to access files
print("Mounting Google Drive...")
drive.mount('/content/drive')

# 2. Install external libraries
print("\nInstalling required libraries...")
# !pip install faiss-cpu sentence-transformers transformers torch
# Out:
# Mounting Google Drive...
# Mounted at /content/drive
#
# Installing required libraries...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 66.3 MB/s eta 0:00:00
# ...

# %%
# !pip install evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.8 MB/s eta 0:00:00
# ...

# %%
CHATBOT_FILE_PATH = "/content/drive/My Drive/Chatbot/Milestone_Chatbot_Final.py"


# %run "{CHATBOT_FILE_PATH}"
# Out:
# Initializing Milestone Chatbot...
# Initialization Complete. Running on device: cpu
#
# ...
# AUTOMATED BATCH RUN - FINAL FORMAT FIXES
# ...
#
# Question 1: what are your measure to ensure accuracy?
# Answer:   We follow strict protocols and procedures to ensure precision in all aspects of our work, from engineering design to manufacturing and installation. Our engineers and site teams adhere to detailed drawings, detailed specifications, and accurate measurements to ensure that every element is executed to the highest standards. We also employ advanced measurement technology and software tools to ensure precise results.
#  PPL Score: 9.0164
# ------------------------------------------------------------
# Question 2: do you have certificates for it?
# ...
